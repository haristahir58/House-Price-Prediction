# ...          ...       ...                 ...          ...             ...
# 1725     -122.37     37.95                35.0     5.375278        3.828641
# 18566    -121.74     36.92                14.0     8.118505        6.545350
# 14413    -117.24     32.78                44.0     7.683864        6.068426
# 974      -121.87     37.66                39.0     6.259581        4.762174
# 12584    -121.44     38.52                38.0     7.640604        5.963579
#
# ...

# %%
train_data = original_train_data.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 train_data = original_train_data.copy()
#
# NameError: name 'original_train_data' is not defined

# %%
one_hot_cols = ['ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND', 'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']

# %%
one_hot_cols = ['ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND', 'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN']

# %%
train_data['ocean_proximity'] = train_data['ocean_proximity'].apply(lambda x: x.split('_')[-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ocean_proximity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
train_data = train_data.drop(one_hot_cols, axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10447    -117.59     33.43                14.0     8.078378        6.184149
# 224      -122.21     37.80                52.0     8.166216        6.568078
# 14160    -117.08     32.76                20.0     7.843064        6.666957
# 12561    -121.46     38.55                40.0     7.639161        6.077642
# 8646     -118.40     33.87                45.0     7.646831        6.210600
# ...          ...       ...                 ...          ...             ...
# 1725     -122.37     37.95                35.0     5.375278        3.828641
# 18566    -121.74     36.92                14.0     8.118505        6.545350
# 14413    -117.24     32.78                44.0     7.683864        6.068426
# 974      -121.87     37.66                39.0     6.259581        4.762174
# 12584    -121.44     38.52                38.0     7.640604        5.963579
#
# ...

# %%
# Assuming 'data' contains 'ocean_proximity' and has the same indices as 'train_data'
train_data['ocean_proximity'] = data['ocean_proximity']

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10447    -117.59     33.43                14.0     8.078378        6.184149
# 224      -122.21     37.80                52.0     8.166216        6.568078
# 14160    -117.08     32.76                20.0     7.843064        6.666957
# 12561    -121.46     38.55                40.0     7.639161        6.077642
# 8646     -118.40     33.87                45.0     7.646831        6.210600
# ...          ...       ...                 ...          ...             ...
# 1725     -122.37     37.95                35.0     5.375278        3.828641
# 18566    -121.74     36.92                14.0     8.118505        6.545350
# 14413    -117.24     32.78                44.0     7.683864        6.068426
# 974      -121.87     37.66                39.0     6.259581        4.762174
# 12584    -121.44     38.52                38.0     7.640604        5.963579
#
# ...

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7240
# INLAND        5221
# NEAR OCEAN    2070
# NEAR BAY      1813
# ISLAND           2
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data['ocean_proximity'], prefix='ocean_proximity', prefix_sep='_')
# Out:
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 10447                      False                   False
# 224                        False                   False
# 14160                      False                   False
# 12561                      False                    True
# 8646                        True                   False
# ...                          ...                     ...
# 1725                       False                   False
# 18566                       True                   False
# 14413                      False                   False
# 974                        False                    True
# 12584                      False                    True
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 10447                   False                     False
# 224                     False                      True
# 14160                   False                     False
# ...

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10447      False   False   False     False        True
# 224        False   False   False      True       False
# 14160      False   False   False     False        True
# 12561      False    True   False     False       False
# 8646        True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 1725       False   False   False      True       False
# 18566       True   False   False     False       False
# 14413      False   False   False     False        True
# 974        False    True   False     False       False
# 12584      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
pd.get_dummies(train_data['ocean_proximity']).astype(int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10447          0       0       0         0           1
# 224            0       0       0         1           0
# 14160          0       0       0         0           1
# 12561          0       1       0         0           0
# 8646           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 1725           0       0       0         1           0
# 18566          1       0       0         0           0
# 14413          0       0       0         0           1
# 974            0       1       0         0           0
# 12584          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10447      False   False   False     False        True
# 224        False   False   False      True       False
# 14160      False   False   False     False        True
# 12561      False    True   False     False       False
# 8646        True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 1725       False   False   False      True       False
# 18566       True   False   False     False       False
# 14413      False   False   False     False        True
# 974        False    True   False     False       False
# 12584      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
pd.get_dummies(train_data['ocean_proximity']).astype(int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10447          0       0       0         0           1
# 224            0       0       0         1           0
# 14160          0       0       0         0           1
# 12561          0       1       0         0           0
# 8646           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 1725           0       0       0         1           0
# 18566          1       0       0         0           0
# 14413          0       0       0         0           1
# 974            0       1       0         0           0
# 12584          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
pd.get_dummies(train_data['ocean_proximity']).astype(int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10447          0       0       0         0           1
# 224            0       0       0         1           0
# 14160          0       0       0         0           1
# 12561          0       1       0         0           0
# 8646           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 1725           0       0       0         1           0
# 18566          1       0       0         0           0
# 14413          0       0       0         0           1
# 974            0       1       0         0           0
# 12584          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
pd.get_dummies(train_data['ocean_proximity']).astype(int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10447          0       0       0         0           1
# 224            0       0       0         1           0
# 14160          0       0       0         0           1
# 12561          0       1       0         0           0
# 8646           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 1725           0       0       0         1           0
# 18566          1       0       0         0           0
# 14413          0       0       0         0           1
# 974            0       1       0         0           0
# 12584          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data = pd.concat([train_data, pd.get_dummies(train_data['ocean_proximity'], prefix='ocean_proximity', prefix_sep='_').astype(int)], axis=1).drop('ocean_proximity', axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10447    -117.59     33.43                14.0     8.078378        6.184149
# 224      -122.21     37.80                52.0     8.166216        6.568078
# 14160    -117.08     32.76                20.0     7.843064        6.666957
# 12561    -121.46     38.55                40.0     7.639161        6.077642
# 8646     -118.40     33.87                45.0     7.646831        6.210600
# ...          ...       ...                 ...          ...             ...
# 1725     -122.37     37.95                35.0     5.375278        3.828641
# 18566    -121.74     36.92                14.0     8.118505        6.545350
# 14413    -117.24     32.78                44.0     7.683864        6.068426
# 974      -121.87     37.66                39.0     6.259581        4.762174
# 12584    -121.44     38.52                38.0     7.640604        5.963579
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data.columns = train_data.columns.str.replace('ocean_proximity_', '')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette= "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot= True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'],axis=1), train_data['median_house_value']

reg = LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
train_data = x_train.join(y_train)

train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10447    -117.59     33.43                14.0     2.205896        1.971877
# 224      -122.21     37.80                52.0     2.215525        2.023939
# 14160    -117.08     32.76                20.0     2.179633        2.036920
# 12561    -121.46     38.55                40.0     2.156305        1.956941
# 8646     -118.40     33.87                45.0     2.157193        1.975552
# ...          ...       ...                 ...          ...             ...
# 1725     -122.37     37.95                35.0     1.852428        1.574565
# 18566    -121.74     36.92                14.0     2.210306        2.020931
# 14413    -117.24     32.78                44.0     2.161467        1.955638
# 974      -121.87     37.66                39.0     1.982322        1.751315
# 12584    -121.44     38.52                38.0     2.156472        1.940694
#
# ...

# %%
test_data = x_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)
test_data = pd.concat([test_data, pd.get_dummies(test_data['ocean_proximity'], prefix='ocean_proximity', prefix_sep='_').astype(int)], axis=1).drop('ocean_proximity', axis=1)
test_data.columns = test_data.columns.str.replace('ocean_proximity_', '')
test_data['bedroom_ratio'] = test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms']/test_data['households']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10471    -117.72     33.49                 4.0     8.195334        6.599870
# 10958    -117.90     33.76                26.0     7.893199        6.555357
# 3290     -122.66     39.03                27.0     7.277248        5.799093
# 5504     -118.43     33.99                43.0     7.817625        6.308098
# 9016     -118.76     34.13                10.0     8.379309        6.575076
# ...          ...       ...                 ...          ...             ...
# 784      -122.11     37.64                31.0     7.305188        5.638355
# 2942     -118.97     35.37                34.0     7.229839        5.811141
# 16253    -121.27     37.96                52.0     6.369901        4.744932
# 15135    -116.92     32.85                23.0     7.229114        5.598422
# 8605     -118.36     33.87                17.0     6.987490        5.676754
#
# ...

# %%
reg.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 reg.score(x_test, y_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:760, in RegressorMixin.score(self, X, y, sample_weight)
#     718 """Return the coefficient of determination of the prediction.
#     719
#     720 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     755 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     756 """
#     758 from .metrics import r2_score
# --> 760 y_pred = self.predict(X)
#     761 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# ...

# %%
x_test, y_test = test_data.drop(['median_house_value'],axis=1), test_data['median_house_value']

# %%
reg.score(x_test, y_test)
# Out:
# 0.6620713791695654

# %%
#Random Forest Model
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.8082083278515402
